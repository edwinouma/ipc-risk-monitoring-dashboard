# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir(r'C:\WORK\IPC-HQ\RAAP - RISK ANALYSIS APPROACH\AFGHANISTAN\CLIMATOLOGICAL\pythonProject\data')

# %%
morbidity_ke = pd.read_excel('morbidity_kenya.xlsx')
morbidity_ke.head(5)
# Out:
#    Month  months  Year       date country adm1_name                sub_county  \
# 0  April       4  2021 2021-04-01   Kenya   Muranga         Kahuro Sub County
# 1  April       4  2021 2021-04-01   Kenya     Nyeri   Mathira West Sub County
# 2  April       4  2021 2021-04-01   Kenya   Nairobi  Embakasi West Sub County
# 3  April       4  2021 2021-04-01   Kenya     Busia        Bunyala Sub County
# 4  April       4  2021 2021-04-01   Kenya     Busia   Teso Central Sub County
#
#   Age cohort  Malaria  Diarrhoea
# 0     >5 yrs      NaN       89.0
# 1     <5 yrs      NaN        NaN
# 2     >5 yrs     66.0      293.0
# 3     >5 yrs   2020.0      145.0
# 4     >5 yrs   3077.0      100.0

# %%
morbidity_ke = morbidity_ke[['country', 'date','adm1_name', 'sub_county', 'Malaria', 'Diarrhoea']]

# %%
morbidity_ke_long = morbidity_ke.melt(id_vars=['country', 'adm1_name', 'sub_county','date'],
                                     value_vars=['Malaria', 'Diarrhoea'],
                                     value_name='value',
                                     var_name='indicator')

# %%
morbidity_ke_long.head(5)
# Out:
#   country adm1_name                sub_county       date indicator   value
# 0   Kenya   Muranga         Kahuro Sub County 2021-04-01   Malaria     NaN
# 1   Kenya     Nyeri   Mathira West Sub County 2021-04-01   Malaria     NaN
# 2   Kenya   Nairobi  Embakasi West Sub County 2021-04-01   Malaria    66.0
# 3   Kenya     Busia        Bunyala Sub County 2021-04-01   Malaria  2020.0
# 4   Kenya     Busia   Teso Central Sub County 2021-04-01   Malaria  3077.0

# %%
# Counties to retain
counties = [
    "Baringo",
    "Embu",
    "Garissa",
    "Isiolo",
    "Kajiado",
    "Kilifi",
    "Kitui",
    "Kwale",
    "Laikipia",
    "Lamu",
    "Makueni",
    "Mandera",
    "Marsabit",
    "Meru",
    "Narok",
    "Nyeri",
    "Samburu",
    "Taita Taveta",
    "Tana River",
    "Tharaka Nithi",
    "Turkana",
    "Wajir",
    "West Pokot",
]

# Keep only these counties
morbidity_ke_long = morbidity_ke_long[
    morbidity_ke_long["adm1_name"].isin(counties)
].copy()

print(f"Rows remaining: {len(morbidity_ke):,}")
print(sorted(morbidity_ke_long["adm1_name"].unique()))
# Out:
# Rows remaining: 35,462
# ['Baringo', 'Embu', 'Garissa', 'Isiolo', 'Kajiado', 'Kilifi', 'Kitui', 'Kwale', 'Laikipia', 'Lamu', 'Makueni', 'Mandera', 'Marsabit', 'Meru', 'Narok', 'Nyeri', 'Samburu', 'Taita Taveta', 'Tana River', 'Tharaka Nithi', 'Turkana', 'Wajir', 'West Pokot']

# %%
# Group by county and indicator
morbidity_ke_long_county = (
    morbidity_ke_long
    .groupby(["country","adm1_name", "indicator","date"], as_index=False)["value"]
    .sum(min_count=1)   # Keeps NaN if all values in a group are NaN
)

print(morbidity_ke_long_county.sample(5))
# Out:
#      country   adm1_name  indicator       date    value
# 2260   Kenya     Turkana    Malaria 2024-11-01  33743.0
# 41     Kenya     Baringo  Diarrhoea 2024-06-01   2884.0
# 723    Kenya       Kitui    Malaria 2022-10-01     39.0
# 2193   Kenya     Turkana  Diarrhoea 2023-10-01   6384.0
# 1981   Kenya  Tana River  Diarrhoea 2024-02-01   1950.0

# %%
morbidity_ke_long_county.to_excel('morbidity_long_kenya.xlsx',index=False)
